# %%
import random
from collections import namedtuple, defaultdict, Counter, deque

# %%
d = deque(range(10000000))
lst = list(range(10000000))

# %%
def rem_ins(lst):
    for _ in range(100):
        num = random.randint(0, 10000)
        lst.insert(num, num)
        lst.remove(num)

# %%
def append(lst):
    for _ in range(1000):
        lst.append(0)

# %%
def lookup(lst):
    for idx in range(10000):
        val = lst[idx]

# %%
# %timeit rem_ins(lst)
# Out:
# 2.03 s ± 49.4 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %%
# %timeit rem_ins(d)
# Out:
# 13.5 ms ± 235 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)

# %%
# %timeit append(lst)
# Out:
# 85.2 µs ± 2.87 µs per loop (mean ± std. dev. of 7 runs, 10000 loops each)

# %%
# %timeit append(d)
# Out:
# 98.1 µs ± 7.65 µs per loop (mean ± std. dev. of 7 runs, 10000 loops each)

# %%
# %timeit lookup(lst)
# Out:
# 527 µs ± 55.6 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)

# %%
# %timeit lookup(d)
# Out:
# 1.99 ms ± 60.6 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)
