# %%
import csv
from collections import defaultdict, namedtuple, Counter, deque
from operator import itemgetter

# %%
MOVIE_DATA = 'movie_metadata.csv'
NUM_TOP_DIRECTORS = 20
MIN_MOVIES = 4
MIN_YEAR = 1960

# %%
Movie = namedtuple('Movie', 'title year score')

# %%
def get_movies_by_director():
    movies_by_director = defaultdict(list)

    with open(MOVIE_DATA, encoding='UTF-8') as fin:
        reader = csv.DictReader(fin)
        for movie in reader:
            movies_by_director[movie['director_name']].append(
                Movie(movie['movie_title'].replace('\xa0', '').strip(), movie['title_year'], movie['imdb_score']))
        return movies_by_director

# %%
def get_average_scores(directors):
    '''Filter out directors with < MIN_MOVIES and calculate averge score'''
    directors = {key: {'score': 
                       _calc_mean(val),
                       'movies':
                       [movie for movie in val if int(movie.year) >= MIN_YEAR]}
                 for key, val in directors.items() 
                 if (len(val) >= MIN_MOVIES) & (key != '')}
    return directors

# %%
def _calc_mean(movies):
    return round(sum(
        [float(movie.score) 
         for movie in movies 
         if int(movie.year) >= MIN_YEAR]
        ) / len(movies), 1)

# %%
def print_results(directors):
    scores = {key: val['score'] for key, val in directors.items()}
    sorted_directors = sorted(scores, key=scores.__getitem__, reverse=True)
       
    for counter, director in enumerate(sorted_directors):     
        if counter == 20:
            break
        vals = directors[director]
        avg = round(vals['score'],1)
        print(f'{counter + 1:02}. {director:<52} {avg}')
        
        for movie in vals['movies']:
            print(f'{movie.year}] {movie.title:<50} {movie.score}')
        print('-' * 60)

# %%
directors = get_movies_by_director()

# %%
_calc_mean(directors['Sergio Leone'])
# directors['Sergio Leone']
# Out:
# 8.5

# %%
directors = get_average_scores(directors)

# %%
print_results(directors)
# Out:
# 01. Sergio Leone                                         8.5
# 1984] Once Upon a Time in America                        8.4
# 1968] Once Upon a Time in the West                       8.6
# 1966] The Good, the Bad and the Ugly                     8.9
# 1964] A Fistful of Dollars                               8.0
# ------------------------------------------------------------
# 02. Christopher Nolan                                    8.4
# 2012] The Dark Knight Rises                              8.5
# 2008] The Dark Knight                                    9.0
# 2014] Interstellar                                       8.6
# 2010] Inception                                          8.8
# 2005] Batman Begins                                      8.3
# 2002] Insomnia                                           7.2
# 2006] The Prestige                                       8.5
# 2000] Memento                                            8.5
# ------------------------------------------------------------
# 03. Quentin Tarantino                                    8.2
# 2012] Django Unchained                                   8.5
# 2009] Inglourious Basterds                               8.3
# 2015] The Hateful Eight                                  7.9
# 2003] Kill Bill: Vol. 1                                  8.1
# 2004] Kill Bill: Vol. 2                                  8.0
# 1997] Jackie Brown                                       7.5
# 1994] Pulp Fiction                                       8.9
# 1992] Reservoir Dogs                                     8.4
# ------------------------------------------------------------
# 04. Hayao Miyazaki                                       8.2
# 2008] Ponyo                                              7.7
# 1997] Kundun                                             7.0
# 1990] Goodfellas                                         8.7
# 1980] Raging Bull                                        8.3
# 1977] New York, New York                                 6.7
# 1986] The Color of Money                                 7.0
# 1988] The Last Temptation of Christ                      7.6
# 1976] Taxi Driver                                        8.3
# 2008] Shine a Light                                      7.2
# 1978] The Last Waltz                                     8.2
# ------------------------------------------------------------
# 13. David Fincher                                        7.7
# 2008] The Curious Case of Benjamin Button                7.8
# 2011] The Girl with the Dragon Tattoo                    7.8
# 2007] Zodiac                                             7.7
# 1999] Fight Club                                         8.8
# 2014] Gone Girl                                          8.1
# 1992] Alien 3                                            6.4
# 1997] The Game                                           7.8
# 2002] Panic Room                                         6.8
# 2010] The Social Network                                 7.7
# 1995] Se7en                                              8.6
# ------------------------------------------------------------
# 14. Matthew Vaughn                                       7.7
# 2011] X-Men: First Class                                 7.8
# 2007] Stardust                                           7.7
# 2010] Kick-Ass                                           7.7
# 2004] Layer Cake                                         7.4
# ------------------------------------------------------------
# 15. Peter Weir                                           7.7
# 2003] Master and Commander: The Far Side of the World    7.4
# 1998] The Truman Show                                    8.1
# 1989] Dead Poets Society                                 8.0
# 1985] Witness                                            7.4
# ------------------------------------------------------------
# 16. Brad Bird                                            7.6
# 2015] Tomorrowland                                       6.5
# 2007] Ratatouille                                        8.0
# 2011] Mission: Impossible - Ghost Protocol               7.4
# 2004] The Incredibles                                    8.0
# 1999] The Iron Giant                                     8.0
# ------------------------------------------------------------
# 17. Paul Greengrass                                      7.6
# 2007] The Bourne Ultimatum                               8.1
# 2016] Jason Bourne                                       7.1
# 2010] Green Zone                                         6.9
# 2004] The Bourne Supremacy                               7.8
# 2013] Captain Phillips                                   7.9
# 2006] United 93                                          7.6
# 2002] Bloody Sunday                                      7.7
# ------------------------------------------------------------
# 18. Spike Jonze                                          7.6
# 2009] Where the Wild Things Are                          6.8
# 2013] Her                                                8.0
# 2002] Adaptation.                                        7.7
# 1999] Being John Malkovich                               7.8
# ------------------------------------------------------------
# 19. Edgar Wright                                         7.6
# 2010] Scott Pilgrim vs. the World                        7.5
# 2013] The World's End                                    7.0
# 2007] Hot Fuzz                                           7.9
# 2004] Shaun of the Dead                                  8.0
# ------------------------------------------------------------
# 20. Wes Anderson                                         7.6
# 2004] The Life Aquatic with Steve Zissou                 7.3
# 2009] Fantastic Mr. Fox                                  7.8
# 2014] The Grand Budapest Hotel                           8.1
# 2001] The Royal Tenenbaums                               7.6
# 2012] Moonrise Kingdom                                   7.8
# 1998] Rushmore                                           7.7
# 1996] Bottle Rocket                                      7.1
# ------------------------------------------------------------

# %%
def test():
    directors = get_movies_by_director()

    assert 'Sergio Leone' in directors
    assert 'Andrew Stanton' in directors  # has 3 movies, but not yet filtered
    assert len(directors['Sergio Leone']) == 4
    assert len(directors['Peter Jackson']) == 12

    movies_sergio = directors['Sergio Leone']
    movies_nolan = directors['Christopher Nolan']
    assert _calc_mean(movies_sergio) == 8.5
    assert _calc_mean(movies_nolan) == 8.4

    directors = get_average_scores(directors)
    assert 'Andrew Stanton' not in directors  # director 3 movies now filtered out

    expected_directors = ['Sergio Leone', 'Christopher Nolan', 'Quentin Tarantino',
                          'Hayao Miyazaki', 'Frank Darabont', 'Stanley Kubrick']
    expected_avg_scores = [8.5, 8.4, 8.2, 8.2, 8.0, 8.0]
    expected_num_movies = [4, 8, 8, 4, 4, 7]
    report = sorted(directors.items(), key=lambda x: float(x[0][1]), reverse=True)
    for counter, (i, j, k) in enumerate(
                            zip(expected_directors,
                                expected_avg_scores, expected_num_movies)):
        assert report[counter][0] == (i, j)
        assert len(report[counter][1]) == k
        assert  _calc_mean(report[counter][1]) == j

    return "tests pass"

# %%
test()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-56-fbd55f77ab7c> in <module>()
# ----> 1 test()
#
# <ipython-input-55-0d6a0763e155> in test()
#      19     expected_avg_scores = [8.5, 8.4, 8.2, 8.2, 8.0, 8.0]
#      20     expected_num_movies = [4, 8, 8, 4, 4, 7]
# ---> 21     report = sorted(directors.items(), key=lambda x: float(x[0][1]), reverse=True)
#      22     for counter, (i, j, k) in enumerate(
#      23                             zip(expected_directors,
#
# <ipython-input-55-0d6a0763e155> in <lambda>(x)
#      19     expected_avg_scores = [8.5, 8.4, 8.2, 8.2, 8.0, 8.0]
#      20     expected_num_movies = [4, 8, 8, 4, 4, 7]
# ---> 21     report = sorted(directors.items(), key=lambda x: float(x[0][1]), reverse=True)
#      22     for counter, (i, j, k) in enumerate(
#      23                             zip(expected_directors,
#
# ValueError: could not convert string to float: 'a'

# %%
directors.items()
# Out:
# dict_items([('James Cameron', {'score': 7.9, 'movies': [Movie(title='Avatar', year='2009', score='7.9'), Movie(title='Titanic', year='1997', score='7.7'), Movie(title='Terminator 2: Judgment Day', year='1991', score='8.5'), Movie(title='True Lies', year='1994', score='7.2'), Movie(title='The Abyss', year='1989', score='7.6'), Movie(title='Aliens', year='1986', score='8.4'), Movie(title='The Terminator', year='1984', score='8.1')]}), ('Gore Verbinski', {'score': 7.0, 'movies': [Movie(title="Pirates of the Caribbean: At World's End", year='2007', score='7.1'), Movie(title="Pirates of the Caribbean: Dead Man's Chest", year='2006', score='7.3'), Movie(title='The Lone Ranger', year='2013', score='6.5'), Movie(title='Rango', year='2011', score='7.2'), Movie(title='Pirates of the Caribbean: The Curse of the Black Pearl', year='2003', score='8.1'), Movie(title='The Mexican', year='2001', score='6.1'), Movie(title='The Weather Man', year='2005', score='6.6')]}), ('Sam Mendes', {'score': 7.5, 'movies': [Movie(title='Spectre', year='2015', score='6.8'), Movie(title='Skyfall', year='2012', score='7.8'), Movie(title='Road to Perdition', year='2002', score='7.7'), Movie(title='Jarhead', year='2005', score='7.1'), Movie(title='Revolutionary Road', year='2008', score='7.3'), Movie(title='Away We Go', year='2009', score='7.1'), Movie(title='American Beauty', year='1999', score='8.4'), Movie(title='Skyfall', year='2012', score='7.8')]}), ('Christopher Nolan', {'score': 8.4, 'movies': [Movie(title='The Dark Knight Rises', year='2012', score='8.5'), Movie(title='The Dark Knight', year='2008', score='9.0'), Movie(title='Interstellar', year='2014', score='8.6'), Movie(title='Inception', year='2010', score='8.8'), Movie(title='Batman Begins', year='2005', score='8.3'), Movie(title='Insomnia', year='2002', score='7.2'), Movie(title='The Prestige', year='2006', score='8.5'), Movie(title='Memento', year='2000', score='8.5')]}), ('Sam Raimi', {'score': 6.9, 'movies': [Movie(title='Spider-Man 3', year='2007', score='6.2'), Movie(title='Spider-Man 2', year='2004', score='7.3'), Movie(title='Oz the Great and Powerful', year='2013', score='6.4'), Movie(title='Spider-Man', year='2002', score='7.3'), Movie(title='For Love of the Game', year='1999', score='6.5'), Movie(title='The Quick and the Dead', year='1995', score='6.4'), Movie(title='Drag Me to Hell', year='2009', score='6.6'), Movie(title='A Simple Plan', year='1998', score='7.5'), Movie(title='Army of Darkness', year='1992', score='7.6'), Movie(title='Spider-Man 3', year='2007', score='6.2'), Movie(title='Evil Dead II', year='1987', score='7.8'), Movie(title='Oz the Great and Powerful', year='2013', score='6.4'), Movie(title='The Evil Dead', year='1981', score='7.6')]}), ('Joss Whedon', {'score': 7.9, 'movies': [Movie(title='Avengers: Age of Ultron', year='2015', score='7.5'), Movie(title='The Avengers', year='2012', score='8.1'), Movie(title='The Avengers', year='2012', score='8.1'), Movie(title='Serenity', year='2005', score='8.0')]}), ('David Yates', {'score': 7.1, 'movies': [Movie(title='Harry Potter and the Half-Blood Prince', year='2009', score='7.5'), Movie(title='The Legend of Tarzan', year='2016', score='6.6'), Movie(title='Harry Potter and the Order of the Phoenix', year='2007', score='7.5'), Movie(title='The Legend of Tarzan', year='2016', score='6.6')]}), ('Zack Snyder', {'score': 7.2, 'movies': [Movie(title='Batman v Superman: Dawn of Justice', year='2016', score='6.9'), Movie(title='Man of Steel', year='2013', score='7.2'), Movie(title='Watchmen', year='2009', score='7.7'), Movie(title="Legend of the Guardians: The Owls of Ga'Hoole", year='2010', score='7.0'), Movie(title='Sucker Punch', year='2011', score='6.1'), Movie(title='300', year='2006', score='7.7'), Movie(title='Dawn of the Dead', year='2004', score='7.4'), Movie(title='Dawn of the Dead', year='2004', score='7.4')]}), ('Bryan Singer', {'score': 7.3, 'movies': [Movie(title='Superman Returns', year='2006', score='6.1'), Movie(titl ...
